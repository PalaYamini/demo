# %%
import pandas as pd

# Load the dataset into a DataFrame
data = pd.read_csv(r'C:\Users\P siva kumar\Downloads\Walmart_Sales.csv')


# Task A: Analyze the performance of sales and revenue at the city and branch level

# Group data by City and Branch and calculate total sales and revenue
city_branch_sales_revenue = data.groupby(['City', 'Branch']).agg({'Quantity': 'sum', 'Unit price': 'sum'}).reset_index()
city_branch_sales_revenue.columns = ['City', 'Branch', 'Total Quantity Sold', 'Total Revenue']

# Task B: What is the average price of an item sold at each branch of the city

# Group data by City and Branch and calculate average price
avg_price_per_branch_city = data.groupby(['City', 'Branch']).agg({'Unit price': 'mean'}).reset_index()
avg_price_per_branch_city.columns = ['City', 'Branch', 'Average Price']

# Task C: Analyze the performance of sales and revenue, Month over Month across the Product line, Gender, and Payment Method, and identify the focus areas to get better sales for April 2019

# Convert Date column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Extract month and year from Date
data['Month'] = data['Date'].dt.month
data['Year'] = data['Date'].dt.year

# Filter data for April 2019
april_2019_data = data[(data['Month'] == 4) & (data['Year'] == 2019)]

# Group data by Product line, Gender, and Payment Method and calculate total sales and revenue
april_2019_performance = april_2019_data.groupby(['Product line', 'Gender', 'Payment']).agg({'Quantity': 'sum', 'Unit price': 'sum'}).reset_index()
april_2019_performance.columns = ['Product line', 'Gender', 'Payment Method', 'Total Quantity Sold', 'Total Revenue']

# Now, you can analyze the performance and identify focus areas as needed

# Displaying the results
print("Task A: Analyze the performance of sales and revenue at the city and branch level")
print(city_branch_sales_revenue)

print("\nTask B: What is the average price of an item sold at each branch of the city")
print(avg_price_per_branch_city)

print("\nTask C: Analyze the performance of sales and revenue, Month over Month across the Product line, Gender, and Payment Method for April 2019")
print(april_2019_performance)
# Out:
# Task A: Analyze the performance of sales and revenue at the city and branch level
#         City Branch  Total Quantity Sold  Total Revenue
# 0   Mandalay      A                637.0        6349.11
# 1   Mandalay      B                664.0        6623.73
# 2   Mandalay      C                519.0        5506.04
# 3  Naypyitaw      A                648.0        5953.55
# 4  Naypyitaw      B                604.0        6298.64
# 5  Naypyitaw      C                579.0        6315.57
# 6     Yangon      A                598.0        6342.88
# 7     Yangon      B                631.0        6329.25
# 8     Yangon      C                630.0        5953.36
#
# Task B: What is the average price of an item sold at each branch of the city
#         City Branch  Average Price
# 0   Mandalay      A      53.353866
# 1   Mandalay      B      56.133305
# 2   Mandalay      C      57.958316
# 3  Naypyitaw      A      54.123182
# 4  Naypyitaw      B      57.785688
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame
data = pd.read_csv(r'C:\Users\P siva kumar\Downloads\Walmart_Sales.csv')

# Task A: Analyze the performance of sales and revenue at the city and branch level

# Group data by City and Branch and calculate total sales and revenue
city_branch_sales_revenue = data.groupby(['City', 'Branch']).agg({'Quantity': 'sum', 'Unit price': 'sum'}).reset_index()
city_branch_sales_revenue.columns = ['City', 'Branch', 'Total Quantity Sold', 'Total Revenue']

# Plotting total quantity sold by city and branch
plt.figure(figsize=(8, 4))
for city in city_branch_sales_revenue['City'].unique():
    plt.bar(city_branch_sales_revenue[city_branch_sales_revenue['City'] == city]['Branch'],
            city_branch_sales_revenue[city_branch_sales_revenue['City'] == city]['Total Quantity Sold'],
            label=city)
plt.xlabel('Branch')
plt.ylabel('Total Quantity Sold')
plt.title('Total Quantity Sold by City and Branch')
plt.legend()
plt.show()

# Plotting total revenue by city and branch
plt.figure(figsize=(8, 4))
for city in city_branch_sales_revenue['City'].unique():
    plt.bar(city_branch_sales_revenue[city_branch_sales_revenue['City'] == city]['Branch'],
            city_branch_sales_revenue[city_branch_sales_revenue['City'] == city]['Total Revenue'],
            label=city)
plt.xlabel('Branch')
plt.ylabel('Total Revenue')
plt.title('Total Revenue by City and Branch')
plt.legend()
plt.show()

# Task B: What is the average price of an item sold at each branch of the city

# Group data by City and Branch and calculate average price
avg_price_per_branch_city = data.groupby(['City', 'Branch']).agg({'Unit price': 'mean'}).reset_index()
avg_price_per_branch_city.columns = ['City', 'Branch', 'Average Price']

# Plotting average price by city and branch
plt.figure(figsize=(8, 4))
for city in avg_price_per_branch_city['City'].unique():
    plt.bar(avg_price_per_branch_city[avg_price_per_branch_city['City'] == city]['Branch'],
            avg_price_per_branch_city[avg_price_per_branch_city['City'] == city]['Average Price'],
            label=city)
plt.xlabel('Branch')
plt.ylabel('Average Price')
plt.title('Average Price by City and Branch')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame
data = pd.read_csv(r'C:\Users\P siva kumar\Downloads\Walmart_Sales.csv')

# Task A: Analyze the performance of sales and revenue at the city and branch level

# Group data by City and Branch and calculate total sales and revenue
city_branch_sales_revenue = data.groupby(['City', 'Branch']).agg({'Quantity': 'sum', 'Unit price': 'sum'}).reset_index()
city_branch_sales_revenue.columns = ['City', 'Branch', 'Total Quantity Sold', 'Total Revenue']

# Displaying results as table
print("Task A: Analyze the performance of sales and revenue at the city and branch level")
print(city_branch_sales_revenue)

# Plotting total quantity sold by city and branch
plt.figure(figsize=(8, 4))
for city in city_branch_sales_revenue['City'].unique():
    plt.bar(city_branch_sales_revenue[city_branch_sales_revenue['City'] == city]['Branch'],
            city_branch_sales_revenue[city_branch_sales_revenue['City'] == city]['Total Quantity Sold'],
            label=city)
plt.xlabel('Branch')
plt.ylabel('Total Quantity Sold')
plt.title('Total Quantity Sold by City and Branch')
plt.legend()
plt.show()

# Plotting total revenue by city and branch
plt.figure(figsize=(8, 4))
for city in city_branch_sales_revenue['City'].unique():
    plt.bar(city_branch_sales_revenue[city_branch_sales_revenue['City'] == city]['Branch'],
            city_branch_sales_revenue[city_branch_sales_revenue['City'] == city]['Total Revenue'],
            label=city)
plt.xlabel('Branch')
plt.ylabel('Total Revenue')
plt.title('Total Revenue by City and Branch')
plt.legend()
plt.show()

# Task B: What is the average price of an item sold at each branch of the city

# Group data by City and Branch and calculate average price
avg_price_per_branch_city = data.groupby(['City', 'Branch']).agg({'Unit price': 'mean'}).reset_index()
avg_price_per_branch_city.columns = ['City', 'Branch', 'Average Price']

# Displaying results as table
print("\nTask B: What is the average price of an item sold at each branch of the city")
print(avg_price_per_branch_city)

# Plotting average price by city and branch
plt.figure(figsize=(8, 4))
for city in avg_price_per_branch_city['City'].unique():
    plt.bar(avg_price_per_branch_city[avg_price_per_branch_city['City'] == city]['Branch'],
            avg_price_per_branch_city[avg_price_per_branch_city['City'] == city]['Average Price'],
            label=city)
plt.xlabel('Branch')
plt.ylabel('Average Price')
plt.title('Average Price by City and Branch')
plt.legend()
plt.show()
# Out:
# Task A: Analyze the performance of sales and revenue at the city and branch level
#         City Branch  Total Quantity Sold  Total Revenue
# 0   Mandalay      A                637.0        6349.11
# 1   Mandalay      B                664.0        6623.73
# 2   Mandalay      C                519.0        5506.04
# 3  Naypyitaw      A                648.0        5953.55
# 4  Naypyitaw      B                604.0        6298.64
# 5  Naypyitaw      C                579.0        6315.57
# 6     Yangon      A                598.0        6342.88
# 7     Yangon      B                631.0        6329.25
# 8     Yangon      C                630.0        5953.36
# Task B: What is the average price of an item sold at each branch of the city
#         City Branch  Average Price
# 0   Mandalay      A      53.353866
# 1   Mandalay      B      56.133305
# 2   Mandalay      C      57.958316
# 3  Naypyitaw      A      54.123182
# 4  Naypyitaw      B      57.785688
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame
data = pd.read_csv(r'C:\Users\P siva kumar\Downloads\Walmart_Sales.csv')

# Convert Date column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Extract month and year from Date
data['Month'] = data['Date'].dt.month
data['Year'] = data['Date'].dt.year

# Filter data for April 2019
april_2019_data = data[(data['Month'] == 4) & (data['Year'] == 2019)]

# Group data by Product line, Gender, and Payment Method and calculate total sales and revenue
monthly_performance = data.groupby(['Month', 'Product line', 'Gender', 'Payment']).agg({'Quantity': 'sum', 'Unit price': 'sum'}).reset_index()
monthly_performance.columns = ['Month', 'Product line', 'Gender', 'Payment Method', 'Total Quantity Sold', 'Total Revenue']

# Displaying results as table
print("Task C: Analyze the performance of sales and revenue, Month over Month across the Product line, Gender, and Payment Method")
print(monthly_performance)

# Identify focus areas for April 2019
april_2019_focus = april_2019_data.groupby(['Product line', 'Gender', 'Payment']).agg({'Quantity': 'sum', 'Unit price': 'sum'}).reset_index()
april_2019_focus.columns = ['Product line', 'Gender', 'Payment Method', 'Total Quantity Sold', 'Total Revenue']

# Displaying focus areas for April 2019
print("\nFocus Areas for April 2019:")
print(april_2019_focus)

# Optionally, you can plot the performance month over month
# Example: Total quantity sold month over month
plt.figure(figsize=(12, 6))
for product_line in monthly_performance['Product line'].unique():
    plt.plot(monthly_performance[monthly_performance['Product line'] == product_line]['Month'],
             monthly_performance[monthly_performance['Product line'] == product_line]['Total Quantity Sold'],
             label=product_line)
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')
plt.title('Total Quantity Sold Month over Month')
plt.legend()
plt.show()
# Out:
# Task C: Analyze the performance of sales and revenue, Month over Month across the Product line, Gender, and Payment Method
#      Month            Product line  Gender Payment Method  \
# 0      1.0  Electronic accessories  Female           Cash
# 1      1.0  Electronic accessories  Female    Credit card
# 2      1.0  Electronic accessories  Female        Ewallet
# 3      1.0  Electronic accessories    Male           Cash
# 4      1.0  Electronic accessories    Male    Credit card
# ..     ...                     ...     ...            ...
# 103    3.0       Sports and travel  Female    Credit card
# 104    3.0       Sports and travel  Female        Ewallet
# 105    3.0       Sports and travel    Male           Cash
# 106    3.0       Sports and travel    Male    Credit card
# 107    3.0       Sports and travel    Male        Ewallet
#
#      Total Quantity Sold  Total Revenue
# 0                   52.0         534.48
# 1                   54.0         371.20
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame
data = pd.read_csv(r'C:\Users\P siva kumar\Downloads\Walmart_Sales.csv')

# Convert Date column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Extract month and year from Date
data['Month'] = data['Date'].dt.month
data['Year'] = data['Date'].dt.year

# Filter data for April 2019
april_2019_data = data[(data['Month'] == 4) & (data['Year'] == 2019)]

# Group data by Product line, Gender, and Payment Method and calculate total sales and revenue
monthly_performance = data.groupby(['Month', 'Product line', 'Gender', 'Payment']).agg({'Quantity': 'sum', 'Unit price': 'sum'}).reset_index()
monthly_performance.columns = ['Month', 'Product line', 'Gender', 'Payment Method', 'Total Quantity Sold', 'Total Revenue']

# Displaying results as table
print("Task C: Analyze the performance of sales and revenue, Month over Month across the Product line, Gender, and Payment Method")
print(monthly_performance)

# Identify focus areas for April 2019
april_2019_focus = april_2019_data.groupby(['Product line', 'Gender', 'Payment']).agg({'Quantity': 'sum', 'Unit price': 'sum'}).reset_index()
april_2019_focus.columns = ['Product line', 'Gender', 'Payment Method', 'Total Quantity Sold', 'Total Revenue']

# Displaying focus areas for April 2019
print("\nFocus Areas for April 2019:")
print(april_2019_focus)

# Plotting the performance month over month (using bar plot)
plt.figure(figsize=(12, 6))
for product_line in monthly_performance['Product line'].unique():
    plt.bar(monthly_performance[monthly_performance['Product line'] == product_line]['Month'],
            monthly_performance[monthly_performance['Product line'] == product_line]['Total Quantity Sold'],
            label=product_line)
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')
plt.title('Total Quantity Sold Month over Month')
plt.legend()
plt.show()
# Out:
# Task C: Analyze the performance of sales and revenue, Month over Month across the Product line, Gender, and Payment Method
#      Month            Product line  Gender Payment Method  \
# 0      1.0  Electronic accessories  Female           Cash
# 1      1.0  Electronic accessories  Female    Credit card
# 2      1.0  Electronic accessories  Female        Ewallet
# 3      1.0  Electronic accessories    Male           Cash
# 4      1.0  Electronic accessories    Male    Credit card
# ..     ...                     ...     ...            ...
# 103    3.0       Sports and travel  Female    Credit card
# 104    3.0       Sports and travel  Female        Ewallet
# 105    3.0       Sports and travel    Male           Cash
# 106    3.0       Sports and travel    Male    Credit card
# 107    3.0       Sports and travel    Male        Ewallet
#
#      Total Quantity Sold  Total Revenue
# 0                   52.0         534.48
# 1                   54.0         371.20
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame
data = pd.read_csv(r'C:\Users\P siva kumar\Downloads\Walmart_Sales.csv')

# Convert Date column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Extract month and year from Date
data['Month'] = data['Date'].dt.month
data['Year'] = data['Date'].dt.year

# Filter data for April 2019
april_2019_data = data[(data['Month'] == 4) & (data['Year'] == 2019)]

# Group data by Product line, Gender, and Payment Method and calculate total sales and revenue
monthly_performance = data.groupby(['Month', 'Product line', 'Gender', 'Payment']).agg({'Quantity': 'sum', 'Unit price': 'sum'}).reset_index()
monthly_performance.columns = ['Month', 'Product line', 'Gender', 'Payment Method', 'Total Quantity Sold', 'Total Revenue']

# Displaying results as table
print("Task C: Analyze the performance of sales and revenue, Month over Month across the Product line, Gender, and Payment Method")
print(monthly_performance)

# Identify focus areas for April 2019
april_2019_focus = april_2019_data.groupby(['Product line', 'Gender', 'Payment']).agg({'Quantity': 'sum', 'Unit price': 'sum'}).reset_index()
april_2019_focus.columns = ['Product line', 'Gender', 'Payment Method', 'Total Quantity Sold', 'Total Revenue']

# Displaying focus areas for April 2019
print("\nFocus Areas for April 2019:")
print(april_2019_focus)

# Plotting the performance month over month (using line plot with markers)
plt.figure(figsize=(12, 6))
for product_line in monthly_performance['Product line'].unique():
    plt.plot(monthly_performance[monthly_performance['Product line'] == product_line]['Month'],
             monthly_performance[monthly_performance['Product line'] == product_line]['Total Quantity Sold'],
             marker='o', label=product_line)
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')
plt.title('Total Quantity Sold Month over Month')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Task C: Analyze the performance of sales and revenue, Month over Month across the Product line, Gender, and Payment Method
#      Month            Product line  Gender Payment Method  \
# 0      1.0  Electronic accessories  Female           Cash
# 1      1.0  Electronic accessories  Female    Credit card
# 2      1.0  Electronic accessories  Female        Ewallet
# 3      1.0  Electronic accessories    Male           Cash
# 4      1.0  Electronic accessories    Male    Credit card
# ..     ...                     ...     ...            ...
# 103    3.0       Sports and travel  Female    Credit card
# 104    3.0       Sports and travel  Female        Ewallet
# 105    3.0       Sports and travel    Male           Cash
# 106    3.0       Sports and travel    Male    Credit card
# 107    3.0       Sports and travel    Male        Ewallet
#
#      Total Quantity Sold  Total Revenue
# 0                   52.0         534.48
# 1                   54.0         371.20
# ...
